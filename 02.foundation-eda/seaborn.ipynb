# %%
#import the nessesary library 
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing the dataset
df = pd.read_csv("car-sales-extended.csv")
df.head()
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0   Honda  White          35431      4  15323
# 1           1     BMW   Blue         192714      5  19943
# 2           2   Honda  White          84714      4  28343
# 3           3  Toyota  White         154365      4  13434
# 4           4  Nissan   Blue         181577      3  14043

# %%
df.shape
# Out:
# (1000, 6)

# %%
sns.set_palette("husl")  # Set a different color palette
sns.scatterplot(x="Make", y="Price", data=df)
plt.show()
