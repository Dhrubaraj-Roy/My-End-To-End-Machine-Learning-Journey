# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhrubaraj-Roy/Python-for-Machine-Learning/blob/main/Data_Frame_SIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = ['Apple','Banana','Organe']
my_list
# Out:
# ['Apple', 'Banana', 'Organe']

# %%
# How to Create Dictionary 
d1={'Mobile':['VIVO','OPPO','SAMSUNG'],'Laptop':['HP','Dell','Lenovo']}
d1
# Out:
# {'Laptop': ['HP', 'Dell', 'Lenovo'], 'Mobile': ['VIVO', 'OPPO', 'SAMSUNG']}

# %%
d1['Mobile']
# Out:
# ['VIVO', 'OPPO', 'SAMSUNG']

# %% [markdown]
# In Line No.2 Mobile & laptop Considered as Key and Vivo and hp considered as elements / objects

# %%
d2={'EmployeeID':[10,11,12],'EmployeeName':['A','B','C'],'EmployeeSalary':[10000,11000,12000]}

# %%
d2
# Out:
# {'EmployeeID': [10, 11, 12],
#  'EmployeeName': ['A', 'B', 'C'],
#  'EmployeeSalary': [10000, 11000, 12000]}

# %% [markdown]
# To Make Unstructured Data to Structed Format - We can Take Support from Well Known Pandas Library
# import pandas as pd # Smiliar to np

# %%
import pandas as pd

# %%
test_1=pd.DataFrame({'EmployeeID':[10,11,12],'EmployeeName':['A','B','C'],'EmployeeSalary':[10000,11000,12000]})

# %%
test_1
# Out:
#    EmployeeID EmployeeName  EmployeeSalary
# 0          10            A           10000
# 1          11            B           11000
# 2          12            C           12000

# %%
#from google.colab import files
#uploaded = files.upload()

# %% [markdown]
# In Case of Traditional ML or DS Most Frequently used File Format
# 1. CSV
# 2. TSV

# %% [markdown]
# How to Read Uploaded Files to Perform analysis

# %%
df=pd.read_csv('AAPL (9).csv')
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 1    2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2    2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 3    2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 4    2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
# ..          ...         ...         ...         ...         ...         ...
# 249  2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
# 250  2022-03-25  173.880005  175.279999  172.750000  174.720001  174.720001
# 251  2022-03-28  172.169998  175.729996  172.000000  175.600006  175.600006
# 252  2022-03-29  176.690002  179.009995  176.339996  178.960007  178.960007
# 253  2022-03-29  176.690002  179.000000  176.339996  178.960007  178.960007
#
#         Volume
# 0     85671900
# 1    118323800
# ...

# %%
# After Reading the Data , We are looking for basic information about my data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       254 non-null    object
#  1   Open       254 non-null    float64
#  2   High       254 non-null    float64
#  3   Low        254 non-null    float64
#  4   Close      254 non-null    float64
#  5   Adj Close  254 non-null    float64
#  6   Volume     254 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.0+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean   150.124213  151.796614  148.703031  150.371063  149.994156
# std     16.291666   16.679493   15.926204   16.346338   16.533648
# min    120.110001  120.400002  118.860001  119.900002  119.191582
# 25%    136.244999  137.135006  134.702503  136.487503  135.911538
# 50%    148.689995  149.739998  147.564995  148.819999  148.372696
# 75%    163.975002  165.662498  161.727501  163.924996  163.872902
# max    182.630005  182.940002  179.119995  182.009995  181.778397
#
#              Volume
# count  2.540000e+02
# mean   8.705781e+07
# std    2.545474e+07
# min    4.100000e+07
# 25%    6.904782e+07
# 50%    8.337400e+07
# 75%    9.974570e+07
# max    1.954327e+08

# %% [markdown]
# Info will provide basic overview of the data and description will provide statistical information above the data

# %%
# If We would like to get first 11 row information

# %%
df.head(11)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
#
head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 1  2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2  2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 3  2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 4  2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
#
#       Volume
# 0   85671900
# 1  118323800
# 2   75089100
# 3   88651200
# 4   80171300

# %%
df.plot()

# %%
df1.plot()

# %%
test_new=df1[(df1['High']>=120)]
test_new
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
# ...                ...         ...         ...         ...         ...
# 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
# 2022-03-25  173.880005  175.279999  172.750000  174.720001  174.720001
# 2022-03-28  172.169998  175.729996  172.000000  175.600006  175.600006
# 2022-03-29  176.690002  179.009995  176.339996  178.960007  178.960007
# 2022-03-29  176.690002  179.000000  176.339996  178.960007  178.960007
#
#                Volume
# Date
# 2021-03-30   85671900
# 2021-03-31  118323800
# 2021-04-01   75089100
# ...

# %%
test_new_1=df1[(df1['Low']<=99)]
test_new_1
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# How to Remove Columns from Dataset 
df1.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
#
#                Volume
# Date
# 2021-03-30   85671900
# 2021-03-31  118323800
# 2021-04-01   75089100
# 2021-04-05   88651200
# 2021-04-06   80171300

# %%
new_1=df1.drop('Volume')
new_1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-0f5fa12f67d0> in <module>()
# ----> 1 new_1=df1.drop('Volume')
#       2 new_1
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %% [markdown]
# If We woulde like to Remove any column we must put axis=1 in case of anything related to row axis=0

# %%
new_1=df1.drop('Volume',axis=1)
new_1
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
# ...                ...         ...         ...         ...         ...
# 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
# 2022-03-25  173.880005  175.279999  172.750000  174.720001  174.720001
# 2022-03-28  172.169998  175.729996  172.000000  175.600006  175.600006
# 2022-03-29  176.690002  179.009995  176.339996  178.960007  178.960007
# 2022-03-29  176.690002  179.000000  176.339996  178.960007  178.960007
#
# [254 rows x 5 columns]

# %% [markdown]
# Read data directly frim html page without download

# %%
df3=pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')
df3
# Out:
# [                                                City  \
#  0                                      Vancouver, BC
#  1                                       Toronto, Ont
#  2                                        Ottawa, Ont
#  3                                       Calgary, Alb
#  4                                      Montreal, Que
#  5                                        Halifax, NS
#  6                                       Regina, Sask
#  7                                    Fredericton, NB
#  8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
#  0                                         $1,036,000
#  1                                           $870,000
#  2                                           $479,000
#  3                                           $410,000
#  4                                           $435,000
#  5                                           $331,000
# ...

# %%
#from google.colab import files 
#uploaded = files.upload()

# %%
fb = pd.read_csv('FB.csv')
fb
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-03-30  289.829987  292.470001  286.700012  288.000000  288.000000
# 1    2021-03-31  289.989990  296.500000  288.609985  294.529999  294.529999
# 2    2021-04-01  298.399994  302.399994  296.600006  298.660004  298.660004
# 3    2021-04-05  300.890015  310.769989  300.679993  308.910004  308.910004
# 4    2021-04-06  308.839996  311.350006  305.250000  306.260010  306.260010
# ..          ...         ...         ...         ...         ...         ...
# 249  2022-03-24  215.000000  220.669998  214.789993  219.570007  219.570007
# 250  2022-03-25  220.509995  225.500000  218.889999  221.820007  221.820007
# 251  2022-03-28  222.130005  224.039993  219.539993  223.589996  223.589996
# 252  2022-03-29  226.070007  230.889999  225.289993  229.860001  229.860001
# 253  2022-03-29  226.070007  230.889999  225.289993  229.860001  229.860001
#
#        Volume
# 0    17474500
# 1    19498200
# ...

# %%
fb1 = pd.read_csv('FB.csv',index_col='Date',parse_dates=True)
fb1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-03-30  289.829987  292.470001  286.700012  288.000000  288.000000
# 2021-03-31  289.989990  296.500000  288.609985  294.529999  294.529999
# 2021-04-01  298.399994  302.399994  296.600006  298.660004  298.660004
# 2021-04-05  300.890015  310.769989  300.679993  308.910004  308.910004
# 2021-04-06  308.839996  311.350006  305.250000  306.260010  306.260010
# ...                ...         ...         ...         ...         ...
# 2022-03-24  215.000000  220.669998  214.789993  219.570007  219.570007
# 2022-03-25  220.509995  225.500000  218.889999  221.820007  221.820007
# 2022-03-28  222.130005  224.039993  219.539993  223.589996  223.589996
# 2022-03-29  226.070007  230.889999  225.289993  229.860001  229.860001
# 2022-03-29  226.070007  230.889999  225.289993  229.860001  229.860001
#
#               Volume
# Date
# 2021-03-30  17474500
# 2021-03-31  19498200
# 2021-04-01  17616000
# ...

# %%
fb2=fb1.drop('Volume', axis=1)
fb2
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2021-03-30  289.829987  292.470001  286.700012  288.000000  288.000000
# 2021-03-31  289.989990  296.500000  288.609985  294.529999  294.529999
# 2021-04-01  298.399994  302.399994  296.600006  298.660004  298.660004
# 2021-04-05  300.890015  310.769989  300.679993  308.910004  308.910004
# 2021-04-06  308.839996  311.350006  305.250000  306.260010  306.260010
# ...                ...         ...         ...         ...         ...
# 2022-03-24  215.000000  220.669998  214.789993  219.570007  219.570007
# 2022-03-25  220.509995  225.500000  218.889999  221.820007  221.820007
# 2022-03-28  222.130005  224.039993  219.539993  223.589996  223.589996
# 2022-03-29  226.070007  230.889999  225.289993  229.860001  229.860001
# 2022-03-29  226.070007  230.889999  225.289993  229.860001  229.860001
#
# [254 rows x 5 columns]

# %%
fb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2021-03-30 to 2022-03-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       254 non-null    float64
#  1   High       254 non-null    float64
#  2   Low        254 non-null    float64
#  3   Close      254 non-null    float64
#  4   Adj Close  254 non-null    float64
#  5   Volume     254 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.9 KB

# %%
fb2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2021-03-30 to 2022-03-29
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       254 non-null    float64
#  1   High       254 non-null    float64
#  2   Low        254 non-null    float64
#  3   Close      254 non-null    float64
#  4   Adj Close  254 non-null    float64
# dtypes: float64(5)
# memory usage: 11.9 KB

# %%
d4=pd.DataFrame({'EmployeeID':[10,11,12],
                 'EmployeeName':['A','B','C'],
                 'EmployeeSalary':[10000,11000,12000],
                 'Year of exp.':[11,13,14]})
d4
# Out:
#    EmployeeID EmployeeName  EmployeeSalary  Year of exp.
# 0          10            A           10000            11
# 1          11            B           11000            13
# 2          12            C           12000            14

# %%
data_new = d4[(d4['Year of exp.']>=12)]
data_new
# Out:
#    EmployeeID EmployeeName  EmployeeSalary  Year of exp.
# 1          11            B           11000            13
# 2          12            C           12000            14

# %% [markdown]
# 1. Matplotlb : Old Player of market - Long coding as well as time taking
# 2. Seaborn : Faster/reliable/real time traking  supported
# 3. Boekh : Most upto date google picassa
# 4. Plotly: Good handsome output
