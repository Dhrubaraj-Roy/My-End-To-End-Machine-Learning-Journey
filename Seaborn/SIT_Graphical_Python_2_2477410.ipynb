# %%
#from google.colab import files 
#uploaded = files.upload()

# %%
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
import seaborn as sns # sns is nothing but alias name same concept as np/pd

# %%
sns.displot(df,x='total_bill')

# %%
sns.displot(df,y='total_bill')

# %%
sns.displot(df,x='total_bill',binwidth=2)
#Binwidth allows user to set building width 
# as per thir choice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# For Better Understanding of the code , we can use object columns which supported by the seaborn library

# %%
sns.displot(df,x='total_bill',hue='sex')
# hue is the built in function clubed or associated with seaborn 
# which helps user to work with object columns

# %%
sns.displot(df,x='total_bill',hue='smoker')

# %%
sns.displot(df,x='total_bill',y='tip')

# %%
sns.displot(df,x='total_bill',y='tip',hue='day')

# %%
sns.catplot(x='sex',y='tip',data=df,hue='smoker')

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='total_bill',y='tip',data=df,hue='sex')

# %% [markdown]
# In this case Due to Close Nature of Each Point, All Point Plotted properly but in normal view it will start display in overlap way-beacuse mostly we are using circle to plot a point-two circle can bemerged or overlap together very easily,if we can change the geometric style of plotting of the points then issue can beresolved properly.

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')
#reg=Regression

# %% [markdown]
# TT Tt
# tT tt

# %%
matrix=df.corr()
matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# y = mx+c
# y depends on mx + c
# x is dependent variable
# c is constant

# %%
sns.heatmap(matrix)

# %%
sns.heatmap(matrix,annot=True)

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# total_bill vs total_bill
# total_bill vs tip
# total_bill vs size

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='day')

# %%
#from google.colab import files 
#uploaded = files.upload()

# %%
test=pd.read_csv('AAPL(9).csv')
test
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 1    2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2    2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 3    2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 4    2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
# ..          ...         ...         ...         ...         ...         ...
# 249  2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
# 250  2022-03-25  173.880005  175.279999  172.750000  174.720001  174.720001
# 251  2022-03-28  172.169998  175.729996  172.000000  175.600006  175.600006
# 252  2022-03-29  176.690002  179.009995  176.339996  178.960007  178.960007
# 253  2022-03-29  176.690002  179.000000  176.339996  178.960007  178.960007
#
#         Volume
# 0     85671900
# 1    118323800
# ...

# %%
test=pd.read_csv('AAPL(9).csv',index_col='Date',parse_dates=True)
test
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-03-30  120.110001  120.400002  118.860001  119.900002  119.191582
# 2021-03-31  121.650002  123.519997  121.150002  122.150002  121.428291
# 2021-04-01  123.660004  124.180000  122.489998  123.000000  122.273262
# 2021-04-05  123.870003  126.160004  123.070000  125.900002  125.156136
# 2021-04-06  126.500000  127.129997  125.650002  126.209999  125.464302
# ...                ...         ...         ...         ...         ...
# 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
# 2022-03-25  173.880005  175.279999  172.750000  174.720001  174.720001
# 2022-03-28  172.169998  175.729996  172.000000  175.600006  175.600006
# 2022-03-29  176.690002  179.009995  176.339996  178.960007  178.960007
# 2022-03-29  176.690002  179.000000  176.339996  178.960007  178.960007
#
#                Volume
# Date
# 2021-03-30   85671900
# 2021-03-31  118323800
# 2021-04-01   75089100
# ...

# %%
sns.pairplot(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-5663ca143e54> in <module>()
# ----> 1 sns.pairplot(test)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2124     diag_kws.setdefault("legend", False)
#    2125     if diag_kind == "hist":
# -> 2126         grid.map_diag(histplot, **diag_kws)
#    2127     elif diag_kind == "kde":
#    2128         diag_kws.setdefault("fill", True)
#
# ...

# %%
test.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.997042  0.996883  0.991472   0.991498  0.236453
# High       0.997042  1.000000  0.996555  0.996346   0.996395  0.267107
# Low        0.996883  0.996555  1.000000  0.995960   0.995902  0.209984
# Close      0.991472  0.996346  0.995960  1.000000   0.999964  0.243027
# Adj Close  0.991498  0.996395  0.995902  0.999964   1.000000  0.242442
# Volume     0.236453  0.267107  0.209984  0.243027   0.242442  1.000000

# %%
sns.heatmap(test.corr(),annot=True)

# %%
sns.jointplot(x='High',y='Close',data=test,kind='hex')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-7bc1ef576041> in <module>()
# ----> 1 sns.jointplot(x='High',y='Close',data=test,kind='hex')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2302         marginal_kws.setdefault("kde", False)
#    2303         marginal_kws.setdefault("color", color)
# -> 2304         grid.plot_marginals(histplot, **marginal_kws)
#    2305
# ...

# %%
#from google.colab import files 
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ba83868-9159-4e8d-a907-0818d1b611cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ba83868-9159-4e8d-a907-0818d1b611cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Employee_Salary.csv to Employee_Salary.csv

# %% [markdown]
# sns.jointplot(x='Years of Experience',y='Salary',data=test1,kind='reg')

# %%
#from google.colab import files 
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-1510046a-6331-4839-882a-fccf0fb4ccdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1510046a-6331-4839-882a-fccf0fb4ccdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EconomiesOfScale.csv to EconomiesOfScale.csv

# %%
t1=pd.read_csv('EconomiesOfScale.csv')
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Number of Units     1000 non-null   float64
#  1   Manufacturing Cost  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
sns.jointplot(x='Number of Units',y='Manufacturing Cost',data=t1,kind='reg')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6bb9ff99-b710-4766-9f96-dcbc66a14964" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bb9ff99-b710-4766-9f96-dcbc66a14964">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Facebook_Ads_2.csv to Facebook_Ads_2.csv

# %%
t2=pd.read_csv('Facebook_Ads_2.csv')
t2
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-50-0312c02e18aa> in <module>()
# ----> 1 t2=pd.read_csv('Facebook_Ads_2.csv')
#       2 t2
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
t2=pd.read_csv('Facebook_Ads_2.csv',encoding='ISO-8859-1')
t2
# Out:
#                Names                                             emails  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 494            Rigel            egestas.blandit.Nam@semvitaealiquam.com
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
#
#                    Country  Time Spent on Site       Salary  Clicked
# ...

# %%
sns.jointplot(x='Time Spent on Site',y='Salary',data=t2)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7d230585-5fba-4077-9a99-24cd2018c373" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d230585-5fba-4077-9a99-24cd2018c373">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Admission.csv to Admission.csv

# %%
t3=pd.read_csv('Admission.csv')
t3
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Admission Chance
# ...

# %%
sns.heatmap(t3.corr())

# %%
sns.jointplot(x='CGPA',y='GRE Score',data=t3)
